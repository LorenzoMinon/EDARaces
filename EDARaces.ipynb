# %%
#import libraries

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
 df.shape
# Out:
# (7461195, 13)

# %%
df.types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14968\2602455961.py in ?()
# ----> 1 df.types
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#Clean up data!

# %%
#Only want Argentina Races, 50km or 50mi, 2020

# %%
#Paso 1 show 50mi or 50km

# %%
df[df['Event distance/length'] == '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#Combine 50km/50mi with isin

# %%
df[df['Event distance/length'].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi']))  & (df['Year of event'] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi']))  & (df['Year of event'] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi']))
& (df['Year of event'] == 2020) & (df['Athlete country'] == 'ARG')]
# Out:
#          Year of event     Event dates  \
# 2553813           2020      19.01.2020
# 2553841           2020      19.01.2020
# 2564398           2020  05.-07.01.2020
# 2575522           2020      18.07.2020
# 2594743           2020      08.03.2020
# ...                ...             ...
# 2599662           2020      07.03.2020
# 2599663           2020      07.03.2020
# 2627032           2020      08.02.2020
# 2698629           2020      19.12.2020
# 2753700           2020      10.10.2020
#
#                                         Event name Event distance/length  \
# 2553813                      Pucón Trail Run (CHI)                  50km
# 2553841                      Pucón Trail Run (CHI)                  50km
# 2564398  Ultra-Trail Tai Mo Shan (YTF) 50 Km (HKG)                  50km
# 2575522            Elephant Trail Race 50 km (AUS)                  50km
# 2594743                Champa Ultra Race 50K (ARG)                  50km
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi']))
& (df['Year of event'] == 2020) & (df['Athlete country'] == 'ARG') &
(df[['Event name'] =='Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 3
# ...

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'ARG']
# Out:
#          Year of event Event dates                               Event name  \
# 7195              2018  17.03.2018  12hs Internacionales de San Pedro (ARG)
# 7196              2018  17.03.2018  12hs Internacionales de San Pedro (ARG)
# 7197              2018  17.03.2018  12hs Internacionales de San Pedro (ARG)
# 7198              2018  17.03.2018  12hs Internacionales de San Pedro (ARG)
# 7199              2018  17.03.2018  12hs Internacionales de San Pedro (ARG)
# ...                ...         ...                                      ...
# 7426153           1995  15.08.1995    Pan American Games - 50 km walk (ARG)
# 7426154           1995  15.08.1995    Pan American Games - 50 km walk (ARG)
# 7426155           1995  15.08.1995    Pan American Games - 50 km walk (ARG)
# 7426156           1995  15.08.1995    Pan American Games - 50 km walk (ARG)
# 7426157           1995  15.08.1995    Pan American Games - 50 km walk (ARG)
#
# ...

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
df2= df[(df['Event distance/length'].isin(['50km','50mi']))
& (df['Year of event'] == 2020) & (df['Athlete country'] == 'ARG') &
(df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'ARG')]

# %%
df2.head(10)
# Out:
#          Year of event Event dates                   Event name  \
# 2594743           2020  08.03.2020  Champa Ultra Race 50K (ARG)
# 2594744           2020  08.03.2020  Champa Ultra Race 50K (ARG)
# 2594745           2020  08.03.2020  Champa Ultra Race 50K (ARG)
# 2594746           2020  08.03.2020  Champa Ultra Race 50K (ARG)
# 2594747           2020  08.03.2020  Champa Ultra Race 50K (ARG)
# 2594748           2020  08.03.2020  Champa Ultra Race 50K (ARG)
# 2594749           2020  08.03.2020  Champa Ultra Race 50K (ARG)
# 2594750           2020  08.03.2020  Champa Ultra Race 50K (ARG)
# 2594751           2020  08.03.2020  Champa Ultra Race 50K (ARG)
# 2594752           2020  08.03.2020  Champa Ultra Race 50K (ARG)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2594743                  50km                        271           5:43:21 h
# 2594744                  50km                        271           6:24:46 h
# ...

# %%
df2.shape
# Out:
# (309, 13)

# %%
#remove (USA) from event name.

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2594743       Champa Ultra Race 50K
# 2594744       Champa Ultra Race 50K
# 2594745       Champa Ultra Race 50K
# 2594746       Champa Ultra Race 50K
# 2594747       Champa Ultra Race 50K
#                      ...
# 2599659    Ushuaia Ultra Trail Race
# 2599660    Ushuaia Ultra Trail Race
# 2599661    Ushuaia Ultra Trail Race
# 2599662    Ushuaia Ultra Trail Race
# 2599663    Ushuaia Ultra Trail Race
# Name: Event name, Length: 309, dtype: object

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\loren\AppData\Local\Temp\ipykernel_14968\3473829760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2df2['Event name'].str.split('(').str.get(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df2df2['Event name'].str.split('(').str.get(0)
#
# NameError: name 'df2df2' is not defined

# %%
df2.loc['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\loren\AppData\Local\Temp\ipykernel_14968\1518446047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.loc['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head(10)
# Out:
#          Year of event Event dates              Event name  \
# 2594743         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594744         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594745         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594746         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594747         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594748         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594749         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594750         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594751         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594752         2020.0  08.03.2020  Champa Ultra Race 50K
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2594743                  50km                      271.0           5:43:21 h
# 2594744                  50km                      271.0           6:24:46 h
# 2594745                  50km                      271.0           6:24:46 h
# ...

# %%
#Clean up athlete age

# %%
df2['Athlete_age'] = 2020 - df2['Athlete year of birth']
# Out:
# C:\Users\loren\AppData\Local\Temp\ipykernel_14968\2583088084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete_age'] = 2020 - df2['Athlete year of birth']

# %%
#remove h from athlete perfomance
# Out:
#   Cell In[58], line 1
#     remove h from athlete perfomance
#            ^
# SyntaxError: invalid syntax

# %%
df2['Athlete performance'].str.split('(').str.get(0)
# Out:
# 2594743        5:43:21 h
# 2594744        6:24:46 h
# 2594745        6:24:46 h
# 2594746        6:41:20 h
# 2594747        6:50:29 h
#                  ...
# 2599660       10:37:16 h
# 2599661       10:38:45 h
# 2599662       10:38:46 h
# 2599663       10:44:16 h
# Event name           NaN
# Name: Athlete performance, Length: 310, dtype: object

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\loren\AppData\Local\Temp\ipykernel_14968\2477507555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(10)
# Out:
#          Year of event Event dates              Event name  \
# 2594743         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594744         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594745         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594746         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594747         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594748         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594749         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594750         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594751         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594752         2020.0  08.03.2020  Champa Ultra Race 50K
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2594743                  50km                      271.0             5:43:21
# 2594744                  50km                      271.0             6:24:46
# 2594745                  50km                      271.0             6:24:46
# ...

# %%
df2.head(5)
# Out:
#          Year of event Event dates              Event name  \
# 2594743         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594744         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594745         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594746         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594747         2020.0  08.03.2020  Champa Ultra Race 50K
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2594743                  50km                      271.0             5:43:21
# 2594744                  50km                      271.0             6:24:46
# 2594745                  50km                      271.0             6:24:46
# 2594746                  50km                      271.0             6:41:20
# 2594747                  50km                      271.0             6:50:29
#
#         Athlete club Athlete country  Athlete year of birth Athlete gender  \
# ...

# %%
#drop columns: Athlete Club, Athlete Country, Athlete year of birth, Athlete age category

# %%
df2 = df2.drop(['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis = 1)

# %%
df2.head()
# Out:
#          Year of event Event dates              Event name  \
# 2594743         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594744         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594745         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594746         2020.0  08.03.2020  Champa Ultra Race 50K
# 2594747         2020.0  08.03.2020  Champa Ultra Race 50K
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2594743                  50km                      271.0             5:43:21
# 2594744                  50km                      271.0             6:24:46
# 2594745                  50km                      271.0             6:24:46
# 2594746                  50km                      271.0             6:41:20
# 2594747                  50km                      271.0             6:50:29
#
#         Athlete gender Athlete average speed  Athlete ID  Athlete_age
# 2594743              M                 8.737    112817.0         31.0
# ...

# %%
#Clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                1
# Event dates                  1
# Event name                   1
# Event distance/length        1
# Event number of finishers    1
# Athlete performance          1
# Athlete gender               1
# Athlete average speed        1
# Athlete ID                   1
# Athlete_age                  2
# dtype: int64

# %%
df2[df2['Athlete_age'].isna()==1]
# Out:
#             Year of event Event dates              Event name  \
# 2594861            2020.0  08.03.2020  Champa Ultra Race 50K
# Event name            NaN         NaN                     NaN
#
#            Event distance/length  Event number of finishers  \
# 2594861                     50km                      271.0
# Event name                   NaN                        NaN
#
#            Athlete performance Athlete gender Athlete average speed  \
# 2594861               10:12:24              M                 4.899
# Event name                 NaN            NaN                   NaN
#
#             Athlete ID  Athlete_age
# 2594861       821658.0          NaN
# Event name         NaN          NaN

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (308, 10)

# %%
#Check dupes

# %%
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athlete_age]
# Index: []

# %%
#reset index

# %%
df2.reset_index(drop = True)
# Out:
#      Year of event Event dates                 Event name  \
# 0           2020.0  08.03.2020     Champa Ultra Race 50K
# 1           2020.0  08.03.2020     Champa Ultra Race 50K
# 2           2020.0  08.03.2020     Champa Ultra Race 50K
# 3           2020.0  08.03.2020     Champa Ultra Race 50K
# 4           2020.0  08.03.2020     Champa Ultra Race 50K
# ..             ...         ...                        ...
# 303         2020.0  07.03.2020  Ushuaia Ultra Trail Race
# 304         2020.0  07.03.2020  Ushuaia Ultra Trail Race
# 305         2020.0  07.03.2020  Ushuaia Ultra Trail Race
# 306         2020.0  07.03.2020  Ushuaia Ultra Trail Race
# 307         2020.0  07.03.2020  Ushuaia Ultra Trail Race
#
#     Event distance/length  Event number of finishers Athlete performance  \
# 0                    50km                      271.0             5:43:21
# 1                    50km                      271.0             6:24:46
# ...

# %%
df2['Athlete_age'] = df2['Athlete_age'].astype(int)
# Out:
# C:\Users\loren\AppData\Local\Temp\ipykernel_14968\1811034274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete_age'] = df2['Athlete_age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)
# Out:
# C:\Users\loren\AppData\Local\Temp\ipykernel_14968\501852820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                float64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                   float64
# Athlete_age                    int32
# dtype: object

# %%
#Rename columns

# %%
df2 = df2.rename(columns ={'Year of event':'year', 'Event dates': 'race_day', 'Event name': 'race_name',
                           'Event distance/length': 'race_length', 'Event number of finishers': 'race_number_of_finishers',
                           'Athlete performance':'athlete_performance', 'Athlete gender': 'athlete_gender',
                           'Athlete average speed': 'athlete_average_speed',
                           'Athlete ID': 'athlete_id'
                          })

# %%
df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %%
df2 = df2.rename(columns ={'Year of event':'year', 'Event dates': 'race_day', 'Event name': 'race_name',
                           'Event distance/length': 'race_length', 'Event number of finishers': 'race_number_of_finishers',
                           'Athlete performance':'athlete_performance', 'Athlete gender': 'athlete_gender',
                           'Athlete average speed': 'athlete_average_speed',
                           'Athlete ID': 'athlete_id'
                          })

# %%
df2.head(5)
# Out:
#            year    race_day               race_name race_length  \
# 2594743  2020.0  08.03.2020  Champa Ultra Race 50K         50km
# 2594744  2020.0  08.03.2020  Champa Ultra Race 50K         50km
# 2594745  2020.0  08.03.2020  Champa Ultra Race 50K         50km
# 2594746  2020.0  08.03.2020  Champa Ultra Race 50K         50km
# 2594747  2020.0  08.03.2020  Champa Ultra Race 50K         50km
#
#          race_number_of_finishers athlete_performance athlete_gender  \
# 2594743                     271.0             5:43:21              M
# 2594744                     271.0             6:24:46              M
# 2594745                     271.0             6:24:46              M
# 2594746                     271.0             6:41:20              M
# 2594747                     271.0             6:50:29              M
#
#          athlete_average_speed  athlete_id  Athlete_age
# 2594743                  8.737    112817.0           31
# ...

# %%
#reorder columns

# %%
df3 = df2[['race_day','race_name','race_length','race_number_of_finishers','athlete_id','athlete_gender','Athlete_age','athlete_performance','athlete_average_speed']]

# %%
df3.head()
# Out:
#            race_day               race_name race_length  \
# 2594743  08.03.2020  Champa Ultra Race 50K         50km
# 2594744  08.03.2020  Champa Ultra Race 50K         50km
# 2594745  08.03.2020  Champa Ultra Race 50K         50km
# 2594746  08.03.2020  Champa Ultra Race 50K         50km
# 2594747  08.03.2020  Champa Ultra Race 50K         50km
#
#          race_number_of_finishers  athlete_id athlete_gender  Athlete_age  \
# 2594743                     271.0    112817.0              M           31
# 2594744                     271.0     50307.0              M           42
# 2594745                     271.0     20777.0              M           41
# 2594746                     271.0    821620.0              M           30
# 2594747                     271.0    677660.0              M           39
#
#         athlete_performance  athlete_average_speed
# 2594743             5:43:21                  8.737
# 2594744             6:24:46                  7.797
# ...

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3, x = 'race_length',hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length'] == '50km']['athlete_average_speed'])

# %%
sns.violinplot(data = df3, x='race_length', y ='athlete_average_speed', hue = 'athlete_gender', split = True, inner = 'quart')
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df3, x= 'Athlete_age', y='athlete_average_speed', hue = 'athlete_gender')

# %%
#Questions I want to find out from the data?

# %%
#Difference in speed for the 50km, male to female

# %%
df3.groupby(['race_length','athlete_gender',])['athlete_average_speed'].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 4.530583
#              M                 4.999631
# Name: athlete_average_speed, dtype: float64

# %%
#What age groups are the best in the 50km race?

# %%
df3.query('race_length == "50km"').groupby('Athlete_age')['athlete_average_speed'].agg(
    ['mean','count']).sort_values('mean', ascending = False).query('count>10')
# Out:
#                  mean  count
# Athlete_age
# 31           5.400308     13
# 36           5.359643     14
# 34           5.218231     13
# 43           5.034200     15
# 33           4.948455     11
# 41           4.920312     16
# 40           4.913400     15
# 35           4.912474     19
# 42           4.785381     21
# 46           4.755187     16
# 44           4.666632     19
# 45           4.525286     14
# 48           4.484273     11

# %%
df3.head(20)
# Out:
#            race_day               race_name race_length  \
# 2594743  08.03.2020  Champa Ultra Race 50K         50km
# 2594744  08.03.2020  Champa Ultra Race 50K         50km
# 2594745  08.03.2020  Champa Ultra Race 50K         50km
# 2594746  08.03.2020  Champa Ultra Race 50K         50km
# 2594747  08.03.2020  Champa Ultra Race 50K         50km
# 2594748  08.03.2020  Champa Ultra Race 50K         50km
# 2594749  08.03.2020  Champa Ultra Race 50K         50km
# 2594750  08.03.2020  Champa Ultra Race 50K         50km
# 2594751  08.03.2020  Champa Ultra Race 50K         50km
# 2594752  08.03.2020  Champa Ultra Race 50K         50km
# 2594753  08.03.2020  Champa Ultra Race 50K         50km
# 2594754  08.03.2020  Champa Ultra Race 50K         50km
# 2594755  08.03.2020  Champa Ultra Race 50K         50km
# 2594756  08.03.2020  Champa Ultra Race 50K         50km
# 2594757  08.03.2020  Champa Ultra Race 50K         50km
# 2594758  08.03.2020  Champa Ultra Race 50K         50km
# ...
